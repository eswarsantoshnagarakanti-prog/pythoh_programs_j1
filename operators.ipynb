# %% [markdown]
# # Operators in python
#   # Python has 6 operators
#   1. arthematic operators
#   2. assigment operators
#   3. comparision operators
#   4. logical operators
#   5. membership operators
#   6. identity operators

# %%
# Arithemic operators +,-,/,*,%,//.
a=10
b=20
c=30
d=40
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
print(d%b)
# Out:
# 30
# -20
# 300
# 2.0
# 2
# 0

# %%
v1=12345
v2=1234657
v3=1456
r=v1+v2/v3*v1%v1-v3
print(r)
# Out:
# 22971.160027472302
