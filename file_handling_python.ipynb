# %% [markdown]
# # file handling in python
# 1. file is a collection of information and stored in memory
# 2. files are two types `1.text files` and `2.binary files`
# 3. text files are `.txt, .py, .doc, .html, .ipynb ....etc`
# 4. binary files - execution files `.exe`

# %% [markdown]
# # file operations
# 1. create file - w mode
# 2. write file - w mode
# 3. read file - r mode
# 4. append file - a mode

# %%
#write a program to create file using python script
create_file=open("profile.txt","w")
print("file created successfully and verified in home directory")
create_file.close()
# Out:
# file created successfully and verified in home directory

# %%
#write a program to write info to profile.txt using python script
write_file=open("profile.txt","w")
data="welcome to python program \nthis program to write info to file"
write_file.write(data)
print("sucessfully info write to file please verfy the file")
write_file.close()
# Out:
# sucessfully info write to file please verfy the file

# %%
#read data from file using python script
